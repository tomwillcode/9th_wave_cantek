# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('BankMarketingTrainData.csv')

# %%
df.head(20)
# Out:
#                  ID  Gender       DOB Lead_Creation_Date City_Code  \
# 0   APPC90493171225  Female  23/07/79           15/07/16    C10001
# 1   APPD40611263344    Male  07/12/86           04/07/16    C10003
# 2   APPE70289249423    Male  10/12/82           19/07/16    C10125
# 3   APPF80273865537    Male  30/01/89           09/07/16    C10477
# 4   APPG60994436641    Male  19/04/85           20/07/16    C10002
# 5   APPI90914237819  Female  23/12/88           01/07/16    C10402
# 6   APPK80327232033    Male  28/03/73           02/07/16    C10022
# 7   APPL20820172146  Female  12/11/90           03/07/16    C10003
# 8   APPM30977401211    Male  03/03/77           02/07/16    C10003
# 9   APPN60714112334  Female  13/12/90           02/07/16    C10014
# 10  APPP50632654511    Male  24/08/83           09/07/16    C10030
# 11  APPS60734495841    Male  11/12/86           08/07/16    C10032
# 12  APPT10286486907  Female  08/03/91           01/07/16    C10001
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69713 entries, 0 to 69712
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   69713 non-null  object
#  1   Gender                               69713 non-null  object
#  2   DOB                                  69698 non-null  object
#  3   Lead_Creation_Date                   69713 non-null  object
#  4   City_Code                            68899 non-null  object
#  5   City_Category                        68899 non-null  object
#  6   Employer_Code                        65695 non-null  object
#  7   Employer_Category1                   65695 non-null  object
#  8   Employer_Category2                   65415 non-null  float64
#  9   Monthly_Income                       69713 non-null  float64
#  10  Customer_Existing_Primary_Bank_Code  60322 non-null  object
# ...

# %%
type(df['DOB'][0])
# Out:
# str

# %%
pd.to_datetime(df['DOB'])
# Out:
# C:\Users\wedwa\AppData\Local\Temp\ipykernel_15164\776841340.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['DOB'])
# 0       1979-07-23
# 1       1986-07-12
# 2       1982-10-12
# 3       1989-01-30
# 4       1985-04-19
#            ...
# 69708   1983-07-31
# 69709   2071-01-27
# 69710   1992-01-02
# 69711   1978-06-27
# 69712   1989-12-31
# Name: DOB, Length: 69713, dtype: datetime64[ns]

# %%
import re

def contains_not_pattern(string):
    pattern = r'[^0-9/]'
    return re.search(pattern, string) is not None

# %%
contains_not_pattern('12-')
# Out:
# True

# %%
df['DOB'].apply(contains_not_pattern)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df['DOB'].apply(contains_not_pattern)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# ...

# %%
df['DOB type'] = df['DOB'].apply(type)

# %%
df.head(20)
# Out:
#                  ID  Gender       DOB Lead_Creation_Date City_Code  \
# 0   APPC90493171225  Female  23/07/79           15/07/16    C10001
# 1   APPD40611263344    Male  07/12/86           04/07/16    C10003
# 2   APPE70289249423    Male  10/12/82           19/07/16    C10125
# 3   APPF80273865537    Male  30/01/89           09/07/16    C10477
# 4   APPG60994436641    Male  19/04/85           20/07/16    C10002
# 5   APPI90914237819  Female  23/12/88           01/07/16    C10402
# 6   APPK80327232033    Male  28/03/73           02/07/16    C10022
# 7   APPL20820172146  Female  12/11/90           03/07/16    C10003
# 8   APPM30977401211    Male  03/03/77           02/07/16    C10003
# 9   APPN60714112334  Female  13/12/90           02/07/16    C10014
# 10  APPP50632654511    Male  24/08/83           09/07/16    C10030
# 11  APPS60734495841    Male  11/12/86           08/07/16    C10032
# 12  APPT10286486907  Female  08/03/91           01/07/16    C10001
# ...

# %%
df['DOB type'].value_counts()
# Out:
# DOB type
# <class 'str'>      69698
# <class 'float'>       15
# Name: count, dtype: int64

# %%
df[df['DOB type'] == float]
# Out:
#                     ID Gender  DOB Lead_Creation_Date City_Code City_Category  \
# 48108  APPF70614332332   Male  NaN           05/09/16    C10004             A
# 48403  APPW20050127804   Male  NaN           05/09/16    C10008             A
# 48405  APPY70297276022   Male  NaN           05/09/16    C10019             B
# 51441  APPI80123699031   Male  NaN           09/09/16    C10002             A
# 59333  APPU10731522427   Male  NaN           20/09/16    C10025             A
# 59334  APPV80984184547   Male  NaN           20/09/16    C10001             A
# 59335  APPW10698163607   Male  NaN           20/09/16    C10001             A
# 59336  APPX10241882727   Male  NaN           20/09/16    C10004             A
# 59337  APPY90481287839   Male  NaN           20/09/16    C10003             A
# 59338  APPZ80978459945   Male  NaN           20/09/16    C10002             A
# 59340  APPB30787013118   Male  NaN           20/09/16    C10020             A
# ...

# %% [markdown]
# The above data-points should likely be deleted, as there are only 15 of them where we have a missing value for the birthday. We can also see missing values for almost all the variables. Seeing as this is very few data points losing them can't impact things much, so it would be a best practice to delete them.

# %%
df = df[df['DOB type'] != float]

# %%
df['DOB'].apply(contains_not_pattern).value_counts()
# Out:
# DOB
# False    69698
# Name: count, dtype: int64

# %%
pd.to_datetime(df['DOB'], format='%d/%m/%y')
# Out:
# 0       1979-07-23
# 1       1986-12-07
# 2       1982-12-10
# 3       1989-01-30
# 4       1985-04-19
#            ...
# 69708   1983-07-31
# 69709   1971-01-27
# 69710   1992-02-01
# 69711   1978-06-27
# 69712   1989-12-31
# Name: DOB, Length: 69713, dtype: datetime64[ns]

# %%
df['DOB_date'] = pd.to_datetime(df['DOB'], format='%d/%m/%y')

# %%
df[df['Lead_Creation_Date'] == np.nan]
# Out:
# Empty DataFrame
# Columns: [ID, Gender, DOB, Lead_Creation_Date, City_Code, City_Category, Employer_Code, Employer_Category1, Employer_Category2, Monthly_Income, Customer_Existing_Primary_Bank_Code, Primary_Bank_Type, Contacted, Source, Source_Category, Existing_EMI, Loan_Amount, Loan_Period, Interest_Rate, EMI, Var1, Approved, DOB type, DOB_date]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['Lead_Creation_Date'].apply(contains_not_pattern).value_counts()
# Out:
# Lead_Creation_Date
# False    69698
# Name: count, dtype: int64

# %%
df['Lead_dateTime'] = pd.to_datetime(df['Lead_Creation_Date'], format='%d/%m/%y')

# %%
df.head(20)
# Out:
#                  ID  Gender       DOB Lead_Creation_Date City_Code  \
# 0   APPC90493171225  Female  23/07/79           15/07/16    C10001
# 1   APPD40611263344    Male  07/12/86           04/07/16    C10003
# 2   APPE70289249423    Male  10/12/82           19/07/16    C10125
# 3   APPF80273865537    Male  30/01/89           09/07/16    C10477
# 4   APPG60994436641    Male  19/04/85           20/07/16    C10002
# 5   APPI90914237819  Female  23/12/88           01/07/16    C10402
# 6   APPK80327232033    Male  28/03/73           02/07/16    C10022
# 7   APPL20820172146  Female  12/11/90           03/07/16    C10003
# 8   APPM30977401211    Male  03/03/77           02/07/16    C10003
# 9   APPN60714112334  Female  13/12/90           02/07/16    C10014
# 10  APPP50632654511    Male  24/08/83           09/07/16    C10030
# 11  APPS60734495841    Male  11/12/86           08/07/16    C10032
# 12  APPT10286486907  Female  08/03/91           01/07/16    C10001
# ...

# %%
df[df['Loan_Amount'].isnull()].describe()
# Out:
#        Employer_Category2  Monthly_Income  Existing_EMI  Loan_Amount  \
# count        23679.000000    27694.000000  27667.000000          0.0
# mean             3.792305     2832.239951    505.402303          NaN
# min              1.000000        0.000000      0.000000          NaN
# 25%              4.000000     1200.000000      0.000000          NaN
# 50%              4.000000     1756.200000      0.000000          NaN
# 75%              4.000000     3000.000000    500.000000          NaN
# max              4.000000   859565.600000  42000.000000          NaN
# std              0.693951     7273.083277   1267.737775          NaN
#
#        Loan_Period  Interest_Rate  EMI          Var1      Approved  \
# count          0.0            0.0  0.0  27694.000000  27694.000000
# mean           NaN            NaN  NaN      1.203690      0.006319
# min            NaN            NaN  NaN      0.000000      0.000000
# 25%            NaN            NaN  NaN      0.000000      0.000000
# ...

# %%
np.nan is np.nan
# Out:
# True

# %%
df[df['Interest_Rate'].isnull()]
# Out:
#                     ID  Gender       DOB Lead_Creation_Date City_Code  \
# 0      APPC90493171225  Female  23/07/79           15/07/16    C10001
# 2      APPE70289249423    Male  10/12/82           19/07/16    C10125
# 3      APPF80273865537    Male  30/01/89           09/07/16    C10477
# 4      APPG60994436641    Male  19/04/85           20/07/16    C10002
# 5      APPI90914237819  Female  23/12/88           01/07/16    C10402
# ...                ...     ...       ...                ...       ...
# 69705  APPR50947529333    Male  01/08/91           30/09/16    C10002
# 69707  APPT50870248519    Male  03/03/91           30/09/16    C10041
# 69708  APPU90955789628  Female  31/07/83           30/09/16    C10006
# 69709  APPV80989824738  Female  27/01/71           30/09/16    C10116
# 69711  APPY50870035036    Male  27/06/78           30/09/16    C10002
#
#       City_Category Employer_Code Employer_Category1  Employer_Category2  \
# ...

# %%
plt.scatter(df['Monthly_Income'], df['Loan_Amount'])

# Customize the plot
plt.xlabel('Monthly_Income')
plt.ylabel('Loan_Amount')
plt.title('Scatter Plot with Multiple Trends')


# Show the plot
plt.show()

# %%
df.describe()
# Out:
#        Employer_Category2  Monthly_Income   Existing_EMI    Loan_Amount  \
# count        65415.000000    6.969800e+04   69647.000000   42004.000000
# mean             3.720187    5.623481e+03     361.006485   39429.982859
# min              1.000000    0.000000e+00       0.000000    5000.000000
# 25%              4.000000    1.650000e+03       0.000000   20000.000000
# 50%              4.000000    2.500000e+03       0.000000   30000.000000
# 75%              4.000000    4.000000e+03     350.000000   50000.000000
# max              4.000000    3.838384e+07  545436.500000  300000.000000
# std              0.807374    1.747858e+05    2288.758228   30727.595990
#
#         Loan_Period  Interest_Rate           EMI          Var1      Approved  \
# count  42004.000000   22276.000000  22276.000000  69698.000000  69698.000000
# mean       3.890629      19.213570   1101.466242      3.949296      0.014635
# min        1.000000      11.990000    118.000000      0.000000      0.000000
# ...

# %%
plt.scatter(np.log(df['Monthly_Income']), df['Loan_Amount'])

# Customize the plot
plt.xlabel('Monthly_Income')
plt.ylabel('Loan_Amount')
plt.title('Scatter Plot with Multiple Trends')


# Show the plot
plt.show()
# Out:
# C:\Users\wedwa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df['log_income'] = np.log(df['Monthly_Income'])

# %%
df['log_loan'] = np.log(df['Loan_Amount'])

# %%
df[['log_income','log_loan']].corr()
# Out:
#             log_income  log_loan
# log_income    1.000000  0.429597
# log_loan      0.429597  1.000000

# %%
df[['log_income','Loan_Amount']].corr()
# Out:
#              log_income  Loan_Amount
# log_income      1.00000      0.52199
# Loan_Amount     0.52199      1.00000

# %%
plt.scatter(df['log_income'], df['Interest_Rate'])

# Customize the plot
plt.xlabel('Monthly_Income')
plt.ylabel('Interest')
plt.title('Scatter Plot')


# Show the plot
plt.show()

# %%
df[['log_income', 'Interest_Rate']].corr()
# Out:
#                log_income  Interest_Rate
# log_income       1.000000      -0.494681
# Interest_Rate   -0.494681       1.000000

# %%
plt.scatter(df['log_income'], (df['Interest_Rate']))

x = df['log_income']
y = df['Interest_Rate']

#add a line of best fit
coefficients = np.polyfit(x, y, 1)
line = np.poly1d(coefficients)
plt.plot(x, line(x), color='red', label='Line of Best Fit')





# Customize the plot
plt.xlabel('Monthly_Income')
plt.ylabel('Interest')
plt.title('Scatter Plot')


# Show the plot
plt.show()
# Out:
# C:\Users\wedwa\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\polynomial.py:668: RuntimeWarning: invalid value encountered in divide
#   lhs /= scale
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[35], line 7
#       4 y = df['Interest_Rate']
#       6 #add a line of best fit
# ----> 7 coefficients = np.polyfit(x, y, 1)
#       8 line = np.poly1d(coefficients)
#       9 plt.plot(x, line(x), color='red', label='Line of Best Fit')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\polynomial.py:669, in polyfit(x, y, deg, rcond, full, w, cov)
#     667 scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     668 lhs /= scale
# --> 669 c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     670 c = (c.T/scale).T  # broadcast scale coefficients
#     672 # warn on rank reduction, which indicates an ill conditioned matrix
#
# ...

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression().fit(df['log_income'], df['Interest_Rate'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 3
#       1 from sklearn.linear_model import LinearRegression
# ----> 3 reg = LinearRegression().fit(df['log_income'], df['Interest_Rate'])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
# ...

# %% [markdown]
# Plan of attack:
# 1) get subset of dataframe with no missing values
# 2) see how other variables impact the interest rate
# 3) create linear model and non-linear polynomial to fit log_income vs interest_rate
# 4) fill in missing values

# %%
df_nona = df.dropna()

# %%
df_nona
# Out:
#                     ID  Gender       DOB Lead_Creation_Date City_Code  \
# 1      APPD40611263344    Male  07/12/86           04/07/16    C10003
# 6      APPK80327232033    Male  28/03/73           02/07/16    C10022
# 7      APPL20820172146  Female  12/11/90           03/07/16    C10003
# 8      APPM30977401211    Male  03/03/77           02/07/16    C10003
# 10     APPP50632654511    Male  24/08/83           09/07/16    C10030
# ...                ...     ...       ...                ...       ...
# 69699  APPE90634962005    Male  01/11/57           30/09/16    C10008
# 69703  APPO60026095033  Female  31/05/82           30/09/16    C10006
# 69704  APPP40131207148    Male  14/10/86           30/09/16    C10001
# 69706  APPS20215136404    Male  04/03/86           30/09/16    C10002
# 69710  APPW50697209842  Female  01/02/92           30/09/16    C10022
#
#       City_Category Employer_Code Employer_Category1  Employer_Category2  \
# ...

# %%
df_nona.groupby("Employer_Category1").describe()
# Out:
#                    Employer_Category2                                     \
#                                 count      mean  min  25%  50%  75%  max
# Employer_Category1
# A                              9271.0  3.697983  1.0  4.0  4.0  4.0  4.0
# B                              6250.0  3.755840  1.0  4.0  4.0  4.0  4.0
# C                              4787.0  3.498433  1.0  4.0  4.0  4.0  4.0
#
#                              Monthly_Income               ... log_income  \
#                          std          count         mean  ...        max
# Employer_Category1                                        ...
# A                   0.880102         9271.0  9188.609503  ...  17.463147
# B                   0.660163         6250.0  5633.169456  ...  15.424948
# C                   1.049818         4787.0  4159.030583  ...  13.180636
#
#                              log_loan                                 \
#                          std    count       mean       min       25%
# ...

# %%
df_nona.groupby("Employer_Category2").describe()['Interest_Rate']
# Out:
#                       count       mean    min    25%    50%    75%   max  \
# Employer_Category2
# 1.0                  1582.0  16.275088  11.99  13.49  14.85  16.75  37.0
# 2.0                   691.0  15.766816  11.99  13.00  14.49  16.75  35.5
# 3.0                   599.0  18.560367  11.99  15.50  18.00  18.40  37.0
# 4.0                 17436.0  19.449120  11.99  15.25  18.15  20.00  37.0
#
#                          std
# Employer_Category2
# 1.0                 4.566139
# 2.0                 4.031131
# 3.0                 5.099845
# 4.0                 5.811191

# %%
plt.scatter(df_nona['EMI'], (df_nona['Interest_Rate']))



#coefficients = np.polyfit(x, y, 1)
#line = np.poly1d(coefficients)
#plt.plot(x, line(x), color='red', label='Line of Best Fit')





# Customize the plot
plt.xlabel('Loan_amt')
plt.ylabel('Interest')
plt.title('Scatter Plot')


# Show the plot
plt.show()

# %%
df_nona.groupby("Var1").describe()['Interest_Rate']
# Out:
#        count       mean    min    25%    50%    75%   max       std
# Var1
# 0      121.0  19.912149  12.99  14.85  18.00  20.00  37.0  6.741685
# 2     6158.0  23.865328  11.99  18.40  20.00  31.50  37.0  6.771803
# 4     3787.0  18.918455  11.99  16.75  18.25  20.00  33.0  4.189282
# 7     5075.0  16.857230  11.99  14.85  15.75  18.25  33.0  3.436937
# 10    5167.0  15.542458  11.99  13.99  15.00  16.00  32.5  2.241942

# %%
df_nona = df_nona.copy(deep = True)

# %%
df_nona['Var1_2'] = (df_nona['Var1'] == 2.0)*1

# %%
df_nona['Var1_0'] = (df_nona['Var1'] == 0)*1
df_nona['Var1_1'] = (df_nona['Var1'] == 4)*1
df_nona['Var1_3'] = (df_nona['Var1'] == 7)*1
df_nona['Var1_4'] = (df_nona['Var1'] == 10)*1

# %%
plt.scatter(df_nona['log_income'], (df_nona['Interest_Rate']))

x = df_nona['log_income']

y = df_nona['Interest_Rate']

#coefficients = np.polyfit(x, y, 2)
#line = np.poly1d(coefficients)
#plt.plot(x, line(x), color='red', label='Line of Best Fit')


# Customize the plot
plt.xlabel('Log_income')
plt.ylabel('Interest')
plt.title('Scatter Plot')

# Show the plot
plt.show()

# %%
df_nona.to_csv('bank_data_nona.csv')

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
# Create the Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=25, max_depth=10, random_state=42)

# Fit the model on the training data
rf_regressor.fit(df_nona[['log_income']], df_nona['Interest_Rate'])

# Predict on the test data
y_pred = rf_regressor.predict(df_nona[['log_income']])

# Evaluate the model
mse = mean_squared_error(df_nona['Interest_Rate'], y_pred)
print("Mean Squared Error:", mse)
# Calculate R-squared value
r_squared = r2_score(df_nona['Interest_Rate'], y_pred)
print("r squared:", r_squared)
# Out:
# Mean Squared Error: 18.373592227800742
# r squared: 0.44396696941052083

# %%
df['interest_na_filled']= np.where(df['Interest_Rate'] is np.nan, rf_regressor.predict(df[['log_income']]),df['Interest_Rate'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df['interest_na_filled']= np.where(df['Interest_Rate'] is np.nan, rf_regressor.predict(df[['log_income']]),df['Interest_Rate'])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:984, in ForestRegressor.predict(self, X)
#     982 check_is_fitted(self)
#     983 # Check data
# --> 984 X = self._validate_X_predict(X)
#     986 # Assign chunk of trees to jobs
#     987 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:599, in BaseForest._validate_X_predict(self, X)
#     596 """
#     597 Validate X whenever one tries to predict, apply, predict_proba."""
#     598 check_is_fitted(self)
# ...

# %%
np.where(df['log_income'] is np.nan, np.nan , rf_regressor.predict([df['log_income']]))
# Out:
# C:\Users\wedwa\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 np.where(df['log_income'] is np.nan, np.nan , rf_regressor.predict([df['log_income']]))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:984, in ForestRegressor.predict(self, X)
#     982 check_is_fitted(self)
#     983 # Check data
# --> 984 X = self._validate_X_predict(X)
#     986 # Assign chunk of trees to jobs
#     987 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:599, in BaseForest._validate_X_predict(self, X)
# ...

# %%
rf_regressor.predict([[df['log_income'][0]]])
# Out:
# C:\Users\wedwa\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([21.37262067])

# %%
df['Interest_Rate'][3] != np.nan
# Out:
# True

# %%
df['Interest_Rate'].apply(lambda x: np.isnan(x))
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 69708     True
# 69709     True
# 69710    False
# 69711     True
# 69712    False
# Name: Interest_Rate, Length: 69698, dtype: bool

# %%
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
df['predicted_interest'] = df['Interest_Rate'].apply(lambda x: np.nan if np.isnan(x) else rf_regressor.predict([[x]])[0])

# %%
df['Interest_Rate']
# Out:
# 0          NaN
# 1        13.25
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 69708      NaN
# 69709      NaN
# 69710    35.50
# 69711      NaN
# 69712    13.99
# Name: Interest_Rate, Length: 69698, dtype: float64

# %%
df['predicted_interest'].value_counts()
# Out:
# predicted_interest
# 14.604148    13306
# 15.390411     2757
# 15.546011     1688
# 15.292958     1373
# 14.946867      692
# 16.054959      650
# 14.855836      487
# 16.381611      420
# 14.761974      222
# 15.814068      206
# 15.199077      174
# 15.422411      169
# 15.227125       66
# 16.310314       66
# Name: count, dtype: int64

# %%
np.where(pd.isna(df['Interest_Rate']), rf_regressor.predict([df['log_income']]),)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 np.where(pd.isna(df['Interest_Rate']), rf_regressor.predict([df['log_income']]),)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:984, in ForestRegressor.predict(self, X)
#     982 check_is_fitted(self)
#     983 # Check data
# --> 984 X = self._validate_X_predict(X)
#     986 # Assign chunk of trees to jobs
#     987 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:599, in BaseForest._validate_X_predict(self, X)
#     596 """
#     597 Validate X whenever one tries to predict, apply, predict_proba."""
#     598 check_is_fitted(self)
# --> 599 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
# ...

# %%
pd.isna(df['Interest_Rate'])

# %%
np.isinf(df[df['Monthly_Income'] == 0]['log_income'][34237])

# %%
np.log(0)

# %%
df['corrected log income'] = np.where(np.isinf(df['log_income']),0,df['log_income'])

# %%
df[['corrected log income','log_income']]

# %%
df['corrected log income'].describe()

# %%
df['log_income'] = np.where(np.isinf(df['log_income']),-3,df['log_income'])

# %%
df['log_income'].describe()

# %%
df['imputed interest'] = np.where(pd.isna(df['Interest_Rate']),rf_regressor.predict(df[['log_income']]),df['Interest_Rate'])

# %%
plt.scatter(df['log_income'], df['imputed interest'])

#x = df_nona['log_income']

#y = df_nona['Interest_Rate']

#coefficients = np.polyfit(x, y, 2)
#line = np.poly1d(coefficients)
#plt.plot(x, line(x), color='red', label='Line of Best Fit')


# Customize the plot
plt.xlabel('Log_income')
plt.ylabel('imputed Interest')
plt.title('Scatter Plot')

# Show the plot
plt.show()

# %%
np.where(pd.isna(df['Interest_Rate']),rf_regressor.predict(df[['log_income']]),df['Interest_Rate'])

# %%
df['imputed interest'].describe()

# %%
df[pd.isna(df['Interest_Rate'])]

# %%
plt.scatter(df['log_income'], df['Interest_Rate'])

#x = df_nona['log_income']

#y = df_nona['Interest_Rate']

#coefficients = np.polyfit(x, y, 2)
#line = np.poly1d(coefficients)
#plt.plot(x, line(x), color='red', label='Line of Best Fit')


# Customize the plot
plt.xlabel('Log_income')
plt.ylabel('imputed Interest')
plt.title('Scatter Plot')

# Show the plot
plt.show()

# %% [markdown]
#     The RFR seems to have potentially overfit the data, a wide range of values for log_income all seem to be predicting the same value for the interest rate, which indicates an overfit. THis could be due to the -infinity values being in the training data, but going forward clearly a better practice on this kind of data is square or cube root to minimize the influence of outliers

# %%
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head(20)
#
# NameError: name 'df' is not defined

# %%
np.log(0)
# Out:
# C:\Users\wedwa\AppData\Local\Temp\ipykernel_12752\4057511574.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(0)
# -inf

# %%
plt.scatter((df['Monthly_Income']), df['Interest_Rate'])

# Customize the plot
plt.xlabel('Monthly_Income')
plt.ylabel('Loan_Amount')
plt.title('Scatter Plot with Multiple Trends')


# Show the plot
plt.show()

# %%
plt.scatter(np.log(df['Monthly_Income']), df['Interest_Rate'])

# Customize the plot
plt.xlabel('Monthly_Income')
plt.ylabel('Loan_Amount')
plt.title('Scatter Plot with Multiple Trends')


# Show the plot
plt.show()

# %%
np.log(df[df['Monthly_Income'] != 0]['Monthly_Income']).describe()
# Out:
# count    69463.000000
# mean         7.875073
# std          0.789306
# min         -2.302585
# 25%          7.408531
# 50%          7.824046
# 75%          8.294050
# max         17.463147
# Name: Monthly_Income, dtype: float64

# %%
pd.DataFrame(np.where(df['Monthly_Income'] != 0,np.log(df['Monthly_Income']),-3)).describe()
# Out:
# C:\Users\wedwa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                   0
# count  69713.000000
# mean       7.836073
# std        1.021458
# min       -3.000000
# 25%        7.408531
# 50%        7.824046
# 75%        8.294050
# max       17.463147

# %%
plt.scatter(np.where(df['Monthly_Income'] != 0,np.log(df['Monthly_Income']),-3), df['Interest_Rate'])

# Customize the plot
plt.xlabel('Monthly_Income')
plt.ylabel('interest rate')
plt.title('Scatter Plot with Multiple Trends')


# Show the plot
plt.show()

# %%
plt.scatter(df['Monthly_Income']**(1/10), df['Interest_Rate'])

# Customize the plot
plt.xlabel('Monthly_Income')
plt.ylabel('interest rate')
plt.title('Scatter Plot with Multiple Trends')


# Show the plot
plt.show()

# %%
from scipy.optimize import curve_fit

# %%
df['log_income'] = np.where(df['Monthly_Income'] != 0,np.log(df['Monthly_Income']),-3)
# Out:
# C:\Users\wedwa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df['root_income'] = df['Monthly_Income']**(1/6)

# %%
df['log_income']
# Out:
# 0        7.600902
# 1        8.160518
# 2        7.718685
# 3        8.160518
# 4        9.210340
#            ...
# 69708    8.496990
# 69709    8.880460
# 69710    7.377759
# 69711    9.199583
# 69712    8.349957
# Name: log_income, Length: 69713, dtype: float64

# %%
df_nona = df.dropna()
df_nona = df_nona.copy(deep = True)

# %% [markdown]
# Below is a great function that one CanTek student brought to my attention. basically, we can use curve_fit from scipy, to find the optimal paramaters based on least-squares, for whatever function we want to fit to the data, so below we don't know the optimal a, and b for that function, but scipy will find them and then fit it.

# %%
def power_law(x, a, b):
    return a * np.power(x, b)

plt.scatter(df_nona['log_income'], df_nona['Interest_Rate'], alpha=0.7, label='Data')

x = df_nona['log_income']
y = df_nona['Interest_Rate']

params, covariance = curve_fit(power_law, x, y)
a, b = params

x_fit = np.linspace(min(x), max(x), 100)
y_fit = power_law(x_fit, a, b)
plt.plot(x_fit, y_fit, color='red', linestyle='-', linewidth=2, label='Power Law Fit')

plt.xlabel('Log of Income', fontsize=12)
plt.ylabel('Interest Rate', fontsize=12)
plt.title('Relationship Between Income and Interest Rate (Power Law)', fontsize=14)
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
covariance
# Out:
# array([[ 7.75513859e+04, -7.80793210e+00],
#        [-7.80793210e+00,  7.86811575e-04]])

# %%
np.linalg.cond(covariance)
# Out:
# 110303052626.22765

# %%
def power_law(x, a, b):
    return a * np.power(x, b)

plt.scatter(df_nona['root_income'], df_nona['Interest_Rate'], alpha=0.7, label='Data')

x = df_nona['root_income']
y = df_nona['Interest_Rate']

params, covariance = curve_fit(power_law, x, y)
a, b = params

x_fit = np.linspace(min(x), max(x), 100)
y_fit = power_law(x_fit, a, b)
plt.plot(x_fit, y_fit, color='red', linestyle='-', linewidth=2, label='Power Law Fit')

plt.xlabel('root Income', fontsize=12)
plt.ylabel('Interest Rate', fontsize=12)
plt.title('Relationship Between Income and Interest Rate (Power Law)', fontsize=14)
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
covariance
# Out:
# array([[ 4.79570053e+01, -1.47236874e-01],
#        [-1.47236874e-01,  4.53830317e-04]])

# %%
np.linalg.cond(covariance)
# Out:
# 26853779.40118816

# %%
def asymptote_func(x, a):
    return ((a/x)) + 15

plt.scatter(df_nona['root_income'], df_nona['Interest_Rate'], alpha=0.7, label='Data')

x = df_nona['root_income']
y = df_nona['Interest_Rate']

params, covariance = curve_fit(asymptote_func, x, y)
a = params

x_fit = np.linspace(min(x), max(x), 100)
y_fit = asymptote_func(x_fit, a)
plt.plot(x_fit, y_fit, color='red', linestyle='-', linewidth=2, label='Power Law Fit')

plt.xlabel('root Income', fontsize=12)
plt.ylabel('Interest Rate', fontsize=12)
plt.title('Relationship Between Income and Interest Rate (Power Law)', fontsize=14)
plt.legend()

plt.grid(True)
#plt.tight_layout()
plt.show()

# %%
covariance
# Out:
# array([[0.0215269]])

# %%
np.linalg.cond(covariance)
# Out:
# 1.0

# %%
def asymptote_func(x, a, b):
    return ((a/x)) + b

plt.scatter(df_nona['root_income'], df_nona['Interest_Rate'], alpha=0.7, label='Data')

x = df_nona['root_income']
y = df_nona['Interest_Rate']

params, covariance = curve_fit(asymptote_func, x, y)
a, b = params

x_fit = np.linspace(min(x), max(x), 100)
y_fit = asymptote_func(x_fit, a, b)
plt.plot(x_fit, y_fit, color='red', linestyle='-', linewidth=2, label='Power Law Fit')

plt.xlabel('root Income', fontsize=12)
plt.ylabel('Interest Rate', fontsize=12)
plt.title('Relationship Between Income and Interest Rate (Power Law)', fontsize=14)
plt.legend()

plt.grid(True)
#plt.tight_layout()
plt.show()

# %%
plt.scatter(df_nona['Lead_dateTime'], df_nona['Interest_Rate'], alpha=0.7, label='Data')





plt.xlabel('date', fontsize=12)
plt.ylabel('loan amount', fontsize=12)
plt.title('time series', fontsize=14)
plt.legend()

plt.grid(True)
#plt.tight_layout()
plt.show()

# %%
df_nona
# Out:
#                     ID  Gender       DOB Lead_Creation_Date City_Code  \
# 1      APPD40611263344    Male  07/12/86           04/07/16    C10003
# 6      APPK80327232033    Male  28/03/73           02/07/16    C10022
# 7      APPL20820172146  Female  12/11/90           03/07/16    C10003
# 8      APPM30977401211    Male  03/03/77           02/07/16    C10003
# 10     APPP50632654511    Male  24/08/83           09/07/16    C10030
# ...                ...     ...       ...                ...       ...
# 69699  APPE90634962005    Male  01/11/57           30/09/16    C10008
# 69703  APPO60026095033  Female  31/05/82           30/09/16    C10006
# 69704  APPP40131207148    Male  14/10/86           30/09/16    C10001
# 69706  APPS20215136404    Male  04/03/86           30/09/16    C10002
# 69710  APPW50697209842  Female  01/02/92           30/09/16    C10022
#
#       City_Category Employer_Code Employer_Category1  Employer_Category2  \
# ...

# %%
df_date = df_nona.groupby('Lead_dateTime')['Interest_Rate'].describe()

# %%
df_date['date'] = (df_nona.groupby('Lead_dateTime')['Lead_dateTime'].describe()['mean'])

# %%
# Out:
# Timestamp('2016-07-01 00:00:00')

# %%
plt.scatter(df_date['date'], df_date['mean'], alpha=0.7, label='Data')





plt.xlabel('date', fontsize=12)
plt.ylabel('loan amount', fontsize=12)
plt.title('time series', fontsize=14)
plt.legend()

plt.grid(True)
#plt.tight_layout()
plt.show()

# %%
df_nona.groupby('Lead_dateTime')['Lead_dateTime'].describe()
# Out:
#               count                 mean                  min  \
# Lead_dateTime
# 2016-07-01      170  2016-07-01 00:00:00  2016-07-01 00:00:00
# 2016-07-02      190  2016-07-02 00:00:00  2016-07-02 00:00:00
# 2016-07-03      148  2016-07-03 00:00:00  2016-07-03 00:00:00
# 2016-07-04      312  2016-07-04 00:00:00  2016-07-04 00:00:00
# 2016-07-05      302  2016-07-05 00:00:00  2016-07-05 00:00:00
# ...             ...                  ...                  ...
# 2016-09-26      312  2016-09-26 00:00:00  2016-09-26 00:00:00
# 2016-09-27      281  2016-09-27 00:00:00  2016-09-27 00:00:00
# 2016-09-28      304  2016-09-28 00:00:00  2016-09-28 00:00:00
# 2016-09-29      349  2016-09-29 00:00:00  2016-09-29 00:00:00
# 2016-09-30      308  2016-09-30 00:00:00  2016-09-30 00:00:00
#
#                                25%                  50%                  75%  \
# Lead_dateTime
# 2016-07-01     2016-07-01 00:00:00  2016-07-01 00:00:00  2016-07-01 00:00:00
# ...

# %%
df_date
# Out:
#                count       mean       std    min     25%     50%     75%  \
# Lead_dateTime
# 2016-07-01     170.0  17.808059  3.415125  13.00  15.125  16.750  20.000
# 2016-07-02     190.0  17.876158  3.698986  12.99  14.850  16.875  20.000
# 2016-07-03     148.0  17.707635  3.102013  13.00  14.850  18.000  20.000
# 2016-07-04     312.0  17.256987  3.195661  12.99  14.850  16.750  20.000
# 2016-07-05     302.0  17.801159  3.370447  12.99  14.885  17.875  20.000
# ...              ...        ...       ...    ...     ...     ...     ...
# 2016-09-26     312.0  20.266090  7.257856  11.99  14.250  16.750  28.500
# 2016-09-27     281.0  19.823915  7.305362  11.99  13.990  16.500  28.500
# 2016-09-28     304.0  19.674638  7.212978  11.99  14.500  16.250  27.375
# 2016-09-29     349.0  20.410201  7.547505  11.99  13.990  16.500  28.500
# 2016-09-30     308.0  20.760974  7.791021  11.99  13.990  16.750  28.500
#
#                 max                 date
# Lead_dateTime
# ...
